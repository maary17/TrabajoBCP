# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SCC_FEB=pd.read_excel("Gestión de Leads_SCC.xlsx")

# %%
SCC_FEB.shape
# Out:
# (62831, 28)

# %%
SCC_FEB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62831 entries, 0 to 62830
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   FECHA_GESTION                   62831 non-null  object
#  1   HORA_GESTION                    62831 non-null  object
#  2   DURACION                        62831 non-null  int64
#  3   DNI_AGENTE                      62831 non-null  int64
#  4   DESCRIPCION_AGENTE              62831 non-null  object
#  5   DESCRIPCION_GRUPO_TIPIFICACION  62831 non-null  object
#  6   DESCRIPCION_TIPIFICACION        62784 non-null  object
#  7   OBSERVACIONES                   4365 non-null   object
#  8   CODIGO_GESTION                  62831 non-null  int64
#  9   CODIGO_AGENTE                   62831 non-null  int64
#  10  TELEFONO_GESTION                62831 non-null  int64
#  11  AFILIADOS                       815 non-null    float64
# ...

# %%
SCC_FEB['DESCRIPCION_GRUPO_TIPIFICACION'].unique()
# Out:
# array(['CONTACTO VÁLIDO', 'NO CONTACTO', 'CONTACTO NO VÁLIDO'],
#       dtype=object)

# %%
SCC_CV=SCC_FEB[SCC_FEB['DESCRIPCION_GRUPO_TIPIFICACION']=='CONTACTO VÁLIDO']

# %%
SCC_CV[SCC_CV['DESCRIPCION_TIPIFICACION']=='VENTA SAP']['DURACION'].max()/60
# Out:
# 59.63333333333333

# %%
SCC_CV.groupby('DESCRIPCION_TIPIFICACION')['DURACION'].mean()
# Out:
# DESCRIPCION_TIPIFICACION
# CLIENTE ENDEUDADO, NO TIENE DINERO                 192.047059
# CLIENTE INTERESADO SEGURO INTEGRAL DE ONCOSALUD    228.300000
# CORTA LLAMADA                                       55.446088
# INFORMES SOBRE PROMOCIONES                         263.335694
# INTERESADO / DESCONFIA TELEFONICAMENTE             262.972973
# INTERESADO / VOLVER A LLAMAR - AGENDADO            480.054217
# NO DESEA / COBERTURA                               192.531250
# NO DESEA / CUENTA OTRO SEGURO                      155.612100
# NO DESEA / DESCONFIA TELEFONICAMENTE               301.526316
# NO DESEA / NO DA RAZÓN                              83.911897
# NO DESEA / PRECIO                                  231.133891
# PENDIENTE RESPUESTA                                915.330827
# PROMOCIONES DIFIEREN CON LOS PRECIOS DE LA WEB      97.000000
# SE ACERCARÁ A ONCOSALUD PARA AFILIACIÓN            164.333333
# VENTA AUNA JOVEN                                     0.000000
# ...

# %%
sns.countplot(x='DESCRIPCION_GRUPO_TIPIFICACION', data=SCC_FEB)
# Out:
# <Axes: xlabel='DESCRIPCION_GRUPO_TIPIFICACION', ylabel='count'>

# %%
SCC_FEB.groupby('DESCRIPCION_GRUPO_TIPIFICACION')['TELEFONO_GESTION'].count()
# Out:
# DESCRIPCION_GRUPO_TIPIFICACION
# CONTACTO NO VÁLIDO    16162
# CONTACTO VÁLIDO       15405
# NO CONTACTO           31264
# Name: TELEFONO_GESTION, dtype: int64

# %%
SCC_ENERO=pd.read_excel("Gestión de Leads_SCC_Enero.xlsx")

# %%
SCC_ENERO.shape
# Out:
# (39516, 28)

# %%
SCC_ENERO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39516 entries, 0 to 39515
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   FECHA_GESTION                   39516 non-null  object
#  1   HORA_GESTION                    39516 non-null  object
#  2   DURACION                        39516 non-null  int64
#  3   DNI_AGENTE                      39516 non-null  int64
#  4   DESCRIPCION_AGENTE              39516 non-null  object
#  5   DESCRIPCION_GRUPO_TIPIFICACION  39516 non-null  object
#  6   DESCRIPCION_TIPIFICACION        39467 non-null  object
#  7   OBSERVACIONES                   5676 non-null   object
#  8   CODIGO_GESTION                  39516 non-null  int64
#  9   CODIGO_AGENTE                   39516 non-null  int64
#  10  TELEFONO_GESTION                39516 non-null  int64
#  11  AFILIADOS                       843 non-null    float64
# ...

# %%
SCC_ENERO['DESCRIPCION_GRUPO_TIPIFICACION'].unique()
# Out:
# array(['NO CONTACTO', 'CONTACTO VÁLIDO', 'CONTACTO NO VÁLIDO'],
#       dtype=object)

# %%
SCC_CV=SCC_ENERO[SCC_ENERO['DESCRIPCION_GRUPO_TIPIFICACION']=='CONTACTO VÁLIDO']

# %%
SCC_CV
# Out:
#       FECHA_GESTION HORA_GESTION  DURACION  DNI_AGENTE  \
# 17       24/01/2023     12:01:57        47    76958319
# 19       24/01/2023     14:50:27         0    48138794
# 20       24/01/2023     21:25:31         0    48584104
# 21       20/01/2023     20:09:07      1333    42223921
# 22       20/01/2023     20:39:53       449    42223921
# ...             ...          ...       ...         ...
# 39503    31/01/2023     18:53:40         0    45834653
# 39506    31/01/2023     17:17:02       390    40623143
# 39512    31/01/2023     19:38:54       649    48584104
# 39513    31/01/2023     18:17:11       380    45834653
# 39515    31/01/2023     19:47:24        56    45834653
#
#                     DESCRIPCION_AGENTE DESCRIPCION_GRUPO_TIPIFICACION  \
# 17                ROXANA CAJA GONZÁLEZ                CONTACTO VÁLIDO
# 19     KARINA LIZET ZAMBRANO AMEZQUITA                CONTACTO VÁLIDO
# 20        INES FRIODELA HUAMANI MARTEL                CONTACTO VÁLIDO
# ...

# %%
SCC_CV[SCC_CV['DESCRIPCION_TIPIFICACION']=='VENTA SAP']['DURACION'].max()/60
# Out:
# 48.016666666666666

# %%
df=SCC_CV.groupby('DESCRIPCION_TIPIFICACION')['DURACION'].mean().reset_index()

# %%
df['DURACION']=round(df['DURACION'],2)

# %%
df['DURACION_MIN']=round(df['DURACION']/60,2)

# %%
df
# Out:
#                            DESCRIPCION_TIPIFICACION  DURACION  DURACION_MIN
# 0                CLIENTE ENDEUDADO, NO TIENE DINERO    190.31          3.17
# 1   CLIENTE INTERESADO SEGURO INTEGRAL DE ONCOSALUD    379.26          6.32
# 2                                     CORTA LLAMADA     71.38          1.19
# 3                     DESEA HACER PAGOS EN EFECTIVO     98.00          1.63
# 4                        INFORMES SOBRE PROMOCIONES    226.48          3.77
# 5            INTERESADO / DESCONFIA TELEFONICAMENTE    197.70          3.30
# 6           INTERESADO / VOLVER A LLAMAR - AGENDADO    554.22          9.24
# 7                              NO DESEA / COBERTURA    229.33          3.82
# 8                     NO DESEA / CUENTA OTRO SEGURO    124.63          2.08
# 9              NO DESEA / DESCONFIA TELEFONICAMENTE    311.96          5.20
# 10                           NO DESEA / NO DA RAZÓN     97.46          1.62
# ...

# %%
SCC_CV[SCC_CV.DESCRIPCION_TIPIFICACION=='VENTA AUNA JOVEN SAP']
# Out:
#       FECHA_GESTION HORA_GESTION  DURACION  DNI_AGENTE  \
# 206      14/01/2023     13:26:40         0    10551621
# 5538     11/01/2023     21:12:32         0    10551621
# 13278    26/01/2023     11:19:06         0    10409229
# 16809    26/01/2023     11:09:02         1    10409229
# 17538    04/01/2023     16:18:18         0    10551621
# 17827    03/01/2023     18:18:35         0    40623143
# 18088    05/01/2023     11:16:03         0    40623143
# 18574    02/01/2023     16:03:28         0    71632270
# 19031    06/01/2023     18:26:29         0    40623143
# 19491    19/01/2023     15:47:16         1    71632270
# 19581    04/01/2023     16:13:03         0    71632270
# 19876    18/01/2023     16:30:04         0    10409229
# 19910    06/01/2023     16:11:57       457    71632270
# 20075    04/01/2023     17:59:38         1    40623143
# 20119    04/01/2023     16:01:46         0    71632270
# 20259    09/01/2023     18:15:44         1    40623143
# ...
