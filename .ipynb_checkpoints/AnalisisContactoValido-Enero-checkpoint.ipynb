# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
SCC_Febrero=pd.read_excel("Gestión de Leads_SCC.xlsx")

# %%
sns.countplot(y='DESCRIPCION_GRUPO_TIPIFICACION', data=SCC_Febrero)
# Out:
# <Axes: xlabel='count', ylabel='DESCRIPCION_GRUPO_TIPIFICACION'>

# %%
SCC_Febrero
# Out:
#       FECHA_GESTION HORA_GESTION  DURACION  DNI_AGENTE  \
# 0        16/02/2023     15:01:11         0    76134563
# 1        02/02/2023     12:42:24       103    44881000
# 2        02/02/2023     12:48:05        23    44881000
# 3        28/02/2023     16:13:52         0    76878427
# 4        09/02/2023     12:45:11         0    72657892
# ...             ...          ...       ...         ...
# 62826    28/02/2023     20:10:38       405    48584104
# 62827    28/02/2023     20:41:05        36    45834653
# 62828    28/02/2023     20:50:33        25    45834653
# 62829    28/02/2023     20:51:05       301    48584104
# 62830    28/02/2023     21:01:32         9    48584104
#
#                     DESCRIPCION_AGENTE DESCRIPCION_GRUPO_TIPIFICACION  \
# 0         MARIA  TERESA NUÑEZ HERRERA                 CONTACTO VÁLIDO
# 1                    ERWIN MACEDO MEZA                CONTACTO VÁLIDO
# 2                    ERWIN MACEDO MEZA                CONTACTO VÁLIDO
# 3           HANNI BETTY  NANCHI MAYAK                     NO CONTACTO
# 4      YOMAIRA CAMILA CAMA ALBINAGORTA                    NO CONTACTO
# ...                                ...                            ...
# 62826     INES FRIODELA HUAMANI MARTEL                CONTACTO VÁLIDO
# 62827        LADY LAURA  CAMA  SANCHEZ                CONTACTO VÁLIDO
# 62828        LADY LAURA  CAMA  SANCHEZ                    NO CONTACTO
# 62829     INES FRIODELA HUAMANI MARTEL             CONTACTO NO VÁLIDO
# 62830     INES FRIODELA HUAMANI MARTEL                    NO CONTACTO
#
#                  DESCRIPCION_TIPIFICACION  \
# 0           NO DESEA / CUENTA OTRO SEGURO
# 1                               VENTA SAP
# 2                               VENTA SAP
# 3                    TIMBRE SIN CONTESTAR
# 4                    TIMBRE SIN CONTESTAR
# ...                                   ...
# 62826  CLIENTE ENDEUDADO, NO TIENE DINERO
# 62827                           VENTA SAP
# 62828                             SISTEMA
# 62829                CUELGA SIN DAR RAZÓN
# 62830                        CONTESTADORA
#
#                              OBSERVACIONES  CODIGO_GESTION  CODIGO_AGENTE  \
# 0                                      NaN        70641054          10206
# 1                          FICHA DE PRUEBA        70413086           7555
# 2                          FICHA DE PRUEBA        70413274           7555
# 3                                      NaN        70859311          10192
# 4                                      NaN        70521577          10172
# ...                                    ...             ...            ...
# 62826  56_x000D_\n54_x000D_\n*********  53        70861487           5635
# 62827          VENTA OK - LADY - PAGO LINK        70861528           2079
# 62828                                  NaN        70861545           2079
# 62829                                  NaN        70861551           5635
# 62830                                  NaN        70861558           5635
#
#        ...    VENTA_ANI  VENTA_CELULAR DNI_CONTRATANTE     NOMBRE_CONTRATANTE  \
# 0      ...          NaN            NaN             NaN                    NaN
# 1      ...          NaN            NaN             NaN                    NaN
# 2      ...          NaN            NaN             NaN                    NaN
# 3      ...          NaN            NaN             NaN                    NaN
# 4      ...          NaN            NaN             NaN                    NaN
# ...    ...          ...            ...             ...                    ...
# 62826  ...          NaN            NaN             NaN                    NaN
# 62827  ...  900167864.0    900167864.0      16175633.0  JOSE LUIS QUISPE NINA
# 62828  ...          NaN            NaN             NaN                    NaN
# 62829  ...          NaN            NaN             NaN                    NaN
# 62830  ...          NaN            NaN             NaN                    NaN
#
#                                       INTEGRACION  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 62826  Leads abandono EECC onco paso 1 prueba SCC
# 62827             Abandono Onco EECC - Contáctame
# 62828  Leads abandono EECC onco paso 1 prueba SCC
# 62829                 Abandono Onco EECC - Paso 0
# 62830                              Duate Onco SCC
#
#                                             UTM_CAMPAIGN  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 62826  DO-GOOGLE-SC-IAFAS-ONCO_ECOM-BRAND_SEARCH-CONV...
# 62827  DO-GOOGLE-SC-IAFAS-ONCO_ECOM-GENERICS_SEARCH-C...
# 62828  DO-FB-FB-IAFAS-MARKETING-CANCERPIEL-CONV-ENE-2023
# 62829  DO-GOOGLE-SC-IAFAS-ONCO_ECOM-BRAND_SEARCH-CONV...
# 62830                                verano_onco_feb2023
#
#                                              UTM_CONTENT  UTM_MEDIUM  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 62826                                    brand_oncosalud         cpc
# 62827                       generics_seguros_oncologicos         cpc
# 62828                                   motivo_protector  paidsocial
# 62829                                    brand_oncosalud         cpc
# 62830  eccOnco_verano_onco_duate_onco_mujeresenr_26-0...       email
#
#        UTM_SOURCE  PRIORIDAD
# 0             NaN          1
# 1             NaN          1
# 2             NaN          1
# 3             NaN          1
# 4             NaN          1
# ...           ...        ...
# 62826      Google          1
# 62827      Google          1
# 62828    facebook          1
# 62829      Google          1
# 62830        bbdd          1
#
# [62831 rows x 28 columns]

# %%
SCC_Febrero.head()
# Out:
#   FECHA_GESTION HORA_GESTION  DURACION  DNI_AGENTE  \
# 0    16/02/2023     15:01:11         0    76134563
# 1    02/02/2023     12:42:24       103    44881000
# 2    02/02/2023     12:48:05        23    44881000
# 3    28/02/2023     16:13:52         0    76878427
# 4    09/02/2023     12:45:11         0    72657892
#
#                 DESCRIPCION_AGENTE DESCRIPCION_GRUPO_TIPIFICACION  \
# 0     MARIA  TERESA NUÑEZ HERRERA                 CONTACTO VÁLIDO
# 1                ERWIN MACEDO MEZA                CONTACTO VÁLIDO
# 2                ERWIN MACEDO MEZA                CONTACTO VÁLIDO
# 3       HANNI BETTY  NANCHI MAYAK                     NO CONTACTO
# 4  YOMAIRA CAMILA CAMA ALBINAGORTA                    NO CONTACTO
#
#         DESCRIPCION_TIPIFICACION    OBSERVACIONES  CODIGO_GESTION  \
# 0  NO DESEA / CUENTA OTRO SEGURO              NaN        70641054
# 1                      VENTA SAP  FICHA DE PRUEBA        70413086
# 2                      VENTA SAP  FICHA DE PRUEBA        70413274
# 3           TIMBRE SIN CONTESTAR              NaN        70859311
# 4           TIMBRE SIN CONTESTAR              NaN        70521577
#
#    CODIGO_AGENTE  ...  VENTA_ANI  VENTA_CELULAR DNI_CONTRATANTE  \
# 0          10206  ...        NaN            NaN             NaN
# 1           7555  ...        NaN            NaN             NaN
# 2           7555  ...        NaN            NaN             NaN
# 3          10192  ...        NaN            NaN             NaN
# 4          10172  ...        NaN            NaN             NaN
#
#   NOMBRE_CONTRATANTE INTEGRACION UTM_CAMPAIGN UTM_CONTENT UTM_MEDIUM  \
# 0                NaN         NaN          NaN         NaN        NaN
# 1                NaN         NaN          NaN         NaN        NaN
# 2                NaN         NaN          NaN         NaN        NaN
# 3                NaN         NaN          NaN         NaN        NaN
# 4                NaN         NaN          NaN         NaN        NaN
#
#    UTM_SOURCE  PRIORIDAD
# 0         NaN          1
# 1         NaN          1
# 2         NaN          1
# 3         NaN          1
# 4         NaN          1
#
# [5 rows x 28 columns]

# %%
SCC_Febrero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62831 entries, 0 to 62830
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   FECHA_GESTION                   62831 non-null  object
#  1   HORA_GESTION                    62831 non-null  object
#  2   DURACION                        62831 non-null  int64
#  3   DNI_AGENTE                      62831 non-null  int64
#  4   DESCRIPCION_AGENTE              62831 non-null  object
#  5   DESCRIPCION_GRUPO_TIPIFICACION  62831 non-null  object
#  6   DESCRIPCION_TIPIFICACION        62784 non-null  object
#  7   OBSERVACIONES                   4365 non-null   object
#  8   CODIGO_GESTION                  62831 non-null  int64
#  9   CODIGO_AGENTE                   62831 non-null  int64
#  10  TELEFONO_GESTION                62831 non-null  int64
#  11  AFILIADOS                       815 non-null    float64
#  12  FRECUENCIA_PAGO                 815 non-null    object
#  13  PROGRAMA_AFILIADO               815 non-null    object
#  14  TIPO_VENTA                      815 non-null    object
#  15  SERVICIO                        815 non-null    object
#  16  BBDD                            62831 non-null  object
#  17  TYPE_LIST_DATE                  62831 non-null  datetime64[ns]
#  18  VENTA_ANI                       815 non-null    float64
#  19  VENTA_CELULAR                   815 non-null    float64
#  20  DNI_CONTRATANTE                 815 non-null    float64
#  21  NOMBRE_CONTRATANTE              812 non-null    object
#  22  INTEGRACION                     45823 non-null  object
#  23  UTM_CAMPAIGN                    39567 non-null  object
#  24  UTM_CONTENT                     36252 non-null  object
#  25  UTM_MEDIUM                      36657 non-null  object
#  26  UTM_SOURCE                      38121 non-null  object
#  27  PRIORIDAD                       62831 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(17)
# memory usage: 13.4+ MB

# %%
SCC_Febrero['DESCRIPCION_GRUPO_TIPIFICACION'].unique()
# Out:
# array(['CONTACTO VÁLIDO', 'NO CONTACTO', 'CONTACTO NO VÁLIDO'],
#       dtype=object)

# %%
telefonos=SCC_Febrero['TELEFONO_GESTION'].unique().tolist()

# %%
telefonos[2]
# Out:
# 982265429

# %%
SCC_Febrero[SCC_Febrero['TELEFONO_GESTION']==982265429]
# Out:
#   FECHA_GESTION HORA_GESTION  DURACION  DNI_AGENTE  \
# 3    28/02/2023     16:13:52         0    76878427
#
#            DESCRIPCION_AGENTE DESCRIPCION_GRUPO_TIPIFICACION  \
# 3  HANNI BETTY  NANCHI MAYAK                     NO CONTACTO
#
#   DESCRIPCION_TIPIFICACION OBSERVACIONES  CODIGO_GESTION  CODIGO_AGENTE  ...  \
# 3     TIMBRE SIN CONTESTAR           NaN        70859311          10192  ...
#
#    VENTA_ANI  VENTA_CELULAR DNI_CONTRATANTE NOMBRE_CONTRATANTE INTEGRACION  \
# 3        NaN            NaN             NaN                NaN         NaN
#
#   UTM_CAMPAIGN UTM_CONTENT UTM_MEDIUM  UTM_SOURCE  PRIORIDAD
# 3          NaN         NaN        NaN         NaN          1
#
# [1 rows x 28 columns]

# %%
df_temp=SCC_Febrero[SCC_Febrero['TELEFONO_GESTION']==982265429]

# %%
df_temp_CV=df_temp[df_temp['DESCRIPCION_GRUPO_TIPIFICACION']=='CONTACTO VÁLIDO']

# %%
df_temp_CV
# Out:
# Empty DataFrame
# Columns: [FECHA_GESTION, HORA_GESTION, DURACION, DNI_AGENTE, DESCRIPCION_AGENTE, DESCRIPCION_GRUPO_TIPIFICACION, DESCRIPCION_TIPIFICACION, OBSERVACIONES, CODIGO_GESTION, CODIGO_AGENTE, TELEFONO_GESTION, AFILIADOS, FRECUENCIA_PAGO, PROGRAMA_AFILIADO, TIPO_VENTA, SERVICIO, BBDD, TYPE_LIST_DATE, VENTA_ANI, VENTA_CELULAR, DNI_CONTRATANTE, NOMBRE_CONTRATANTE, INTEGRACION, UTM_CAMPAIGN, UTM_CONTENT, UTM_MEDIUM, UTM_SOURCE, PRIORIDAD]
# Index: []
#
# [0 rows x 28 columns]

# %%
df_temp_CV.empty
# Out:
# True

# %%
DF_final=pd.DataFrame(columns=SCC_Febrero.columns.tolist())

# %%
DF_final
# Out:
# Empty DataFrame
# Columns: [FECHA_GESTION, HORA_GESTION, DURACION, DNI_AGENTE, DESCRIPCION_AGENTE, DESCRIPCION_GRUPO_TIPIFICACION, DESCRIPCION_TIPIFICACION, OBSERVACIONES, CODIGO_GESTION, CODIGO_AGENTE, TELEFONO_GESTION, AFILIADOS, FRECUENCIA_PAGO, PROGRAMA_AFILIADO, TIPO_VENTA, SERVICIO, BBDD, TYPE_LIST_DATE, VENTA_ANI, VENTA_CELULAR, DNI_CONTRATANTE, NOMBRE_CONTRATANTE, INTEGRACION, UTM_CAMPAIGN, UTM_CONTENT, UTM_MEDIUM, UTM_SOURCE, PRIORIDAD]
# Index: []
#
# [0 rows x 28 columns]

# %%
for i in telefonos: 
    df_temp=SCC_Febrero[SCC_Febrero['TELEFONO_GESTION']==i]
    df_temp_CV=df_temp[df_temp['DESCRIPCION_GRUPO_TIPIFICACION']=='CONTACTO VÁLIDO']
    if df_temp_CV.empty==True:
        df_concatenar=df_temp
    else: 
        df_concatenar=df_temp_CV
    DF_final=pd.concat([DF_final, df_concatenar], ignore_index=True)

# %%
SCC_Febrero.groupby('DESCRIPCION_GRUPO_TIPIFICACION')['TELEFONO_GESTION'].nunique()
# Out:
# DESCRIPCION_GRUPO_TIPIFICACION
# CONTACTO NO VÁLIDO    13371
# CONTACTO VÁLIDO        9651
# NO CONTACTO           12856
# Name: TELEFONO_GESTION, dtype: int64

# %%
DF_final.groupby('DESCRIPCION_GRUPO_TIPIFICACION')['TELEFONO_GESTION'].nunique()
# Out:
# DESCRIPCION_GRUPO_TIPIFICACION
# CONTACTO NO VÁLIDO    9195
# CONTACTO VÁLIDO       9651
# NO CONTACTO           8374
# Name: TELEFONO_GESTION, dtype: int64

# %%
DF_Sin_algoritmo=SCC_Febrero.groupby('DESCRIPCION_GRUPO_TIPIFICACION')['TELEFONO_GESTION'].nunique().reset_index()

# %%
DF_Con_algoritmo=DF_final.groupby('DESCRIPCION_GRUPO_TIPIFICACION')['TELEFONO_GESTION'].nunique().reset_index()

# %%
DF_Sin_algoritmo
# Out:
#   DESCRIPCION_GRUPO_TIPIFICACION  TELEFONO_GESTION
# 0             CONTACTO NO VÁLIDO             13371
# 1                CONTACTO VÁLIDO              9651
# 2                    NO CONTACTO             12856

# %%
DF_Con_algoritmo
# Out:
#   DESCRIPCION_GRUPO_TIPIFICACION  TELEFONO_GESTION
# 0             CONTACTO NO VÁLIDO              9195
# 1                CONTACTO VÁLIDO              9651
# 2                    NO CONTACTO              8374

# %%
DF_Sin_algoritmo['TELEFONO_GESTION_Algoritmo']=DF_Con_algoritmo['TELEFONO_GESTION']

# %%
DF_Sin_algoritmo
# Out:
#   DESCRIPCION_GRUPO_TIPIFICACION  TELEFONO_GESTION  TELEFONO_GESTION_Algoritmo
# 0             CONTACTO NO VÁLIDO             13371                        9195
# 1                CONTACTO VÁLIDO              9651                        9651
# 2                    NO CONTACTO             12856                        8374

# %%
DF_Sin_algoritmo.columns
# Out:
# Index(['DESCRIPCION_GRUPO_TIPIFICACION', 'TELEFONO_GESTION',
#        'TELEFONO_GESTION_Algoritmo'],
#       dtype='object')

# %%
DF_Sin_algoritmo.columns=['DESCRIPCION_GRUPO_TIPIFICACION', '# LEADS SIN ALGORITMO',
       '# LEADS CON ALGORITMO']

# %%
DF_Sin_algoritmo
# Out:
#   DESCRIPCION_GRUPO_TIPIFICACION  # LEADS SIN ALGORITMO  # LEADS CON ALGORITMO
# 0             CONTACTO NO VÁLIDO                  13371                   9195
# 1                CONTACTO VÁLIDO                   9651                   9651
# 2                    NO CONTACTO                  12856                   8374

# %%
DF_Sin_algoritmo['# LEADS SIN ALGORITMO %'] = DF_Sin_algoritmo['# LEADS SIN ALGORITMO'].apply(lambda x: "{:.2%}".format(x/DF_Sin_algoritmo['# LEADS SIN ALGORITMO'].sum()))

# %%
DF_Sin_algoritmo
# Out:
#   DESCRIPCION_GRUPO_TIPIFICACION  # LEADS SIN ALGORITMO  \
# 0             CONTACTO NO VÁLIDO                  13371
# 1                CONTACTO VÁLIDO                   9651
# 2                    NO CONTACTO                  12856
#
#    # LEADS CON ALGORITMO # LEADS SIN ALGORITMO %
# 0                   9195                  37.27%
# 1                   9651                  26.90%
# 2                   8374                  35.83%

# %%
DF_Sin_algoritmo['# LEADS CON ALGORITMO %'] = DF_Sin_algoritmo['# LEADS CON ALGORITMO'].apply(lambda x: "{:.2%}".format(x/DF_Sin_algoritmo['# LEADS CON ALGORITMO'].sum()))

# %%
DF_Sin_algoritmo
# Out:
#   DESCRIPCION_GRUPO_TIPIFICACION  # LEADS SIN ALGORITMO  \
# 0             CONTACTO NO VÁLIDO                  13371
# 1                CONTACTO VÁLIDO                   9651
# 2                    NO CONTACTO                  12856
#
#    # LEADS CON ALGORITMO # LEADS SIN ALGORITMO % # LEADS CON ALGORITMO %
# 0                   9195                  37.27%                  33.78%
# 1                   9651                  26.90%                  35.46%
# 2                   8374                  35.83%                  30.76%

# %%
DF_Sin_algoritmo.columns
# Out:
# Index(['DESCRIPCION_GRUPO_TIPIFICACION', '# LEADS SIN ALGORITMO',
#        '# LEADS CON ALGORITMO', '# LEADS SIN ALGORITMO %',
#        '# LEADS CON ALGORITMO %'],
#       dtype='object')

# %%
DF_Sin_algoritmo=DF_Sin_algoritmo[['DESCRIPCION_GRUPO_TIPIFICACION', '# LEADS SIN ALGORITMO', '# LEADS SIN ALGORITMO %', '# LEADS CON ALGORITMO', '# LEADS CON ALGORITMO %' ]]

# %%
DF_Sin_algoritmo.columns=['TIPIFICACION', '# LEADS S/A',
       '% LEADS S/A', '# LEADS C/A',
       '% LEADS C/A']

# %%
DF_Sin_algoritmo
# Out:
#          TIPIFICACION  # LEADS S/A % LEADS S/A  # LEADS C/A % LEADS C/A
# 0  CONTACTO NO VÁLIDO        13371      37.27%         9195      33.78%
# 1     CONTACTO VÁLIDO         9651      26.90%         9651      35.46%
# 2         NO CONTACTO        12856      35.83%         8374      30.76%
